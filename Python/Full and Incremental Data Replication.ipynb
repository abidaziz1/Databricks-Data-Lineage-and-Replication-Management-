# %%
from pyspark.sql import SparkSession

# %%
# Azure Blob Storage details
storage_account_name = "<storage-account-name>"
storage_account_key = "<storage-access-key>"  
container_name = "output"

# %%
# Setting up the Spark configuration for Azure Blob Storage authentication
spark.conf.set(f"fs.azure.account.key.{storage_account_name}.blob.core.windows.net", storage_account_key)

# %%
df = spark.read.csv(f"wasbs://{container_name}@{account_name}.blob.core.windows.net/sql_server/dbo.Employee")

# %%
df1.count()

# %%
df1.filter("employee_id==100").display()
